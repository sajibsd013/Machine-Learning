# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("canada_per_capita_income.csv")

df.head(5)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
year = df.drop("per capita income (US$)",  axis="columns")
pci = df['per capita income (US$)']

# %%
plt.scatter(year, pci, color="black", marker="+")
plt.xlabel("Year")
plt.ylabel("per capita income (US$)")
plt.show()

# %%
model = LinearRegression()
model.fit(year, pci)
model.predict([[2020]])
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
